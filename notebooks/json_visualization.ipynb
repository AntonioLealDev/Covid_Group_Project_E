# %% [markdown]
# # EDA COVID PROJECT

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import sys
import os
import json
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import modules

# %%
"""
Insert your file's path
"""

sys.path.append(os.path.dirname(os.path.dirname('C:\\Users\\usuario\\Desktop\\alumno_data_sciece\\data_science\\Trabajo_COVID_grupal\\notebooks\\json_visualization')))

# %%
from src.utils import folders_tb as ft
from src.utils import mining_data_tb as mdt
from src.utils import visualization_tb as vt

# %% [markdown]
# ### Objetcs

# %%
variable_creator = ft.Folders()
variable_miner = mdt.Miner()
variable_visual = vt.Visualization()

# %% [markdown]
# ## JSON

# %%
with open('..\\data\\jsonpaalexjaviyantonio.json', 'r+') as outfile:
    json_readed = json.load(outfile)

# %%
df_json = pd.DataFrame(json_readed)

dates = []
means = []

for i in df_json['t_d_averages']:
    dates.append(i[0])
    means.append(i[1])

df_json['Date'] = dates
df_json['Total Deaths Mean'] = means
df_json = df_json.drop(['t_d_averages'], axis=1)

# %%
df_json
# Out:
#            Date  Total Deaths Mean
# 0    2020-03-03                1.0
# 1    2020-03-04                2.0
# 2    2020-03-05                3.0
# 3    2020-03-06                3.0
# 4    2020-03-07                6.0
# ..          ...                ...
# 317  2021-01-14            34442.2
# 318  2021-01-15            34812.8
# 319  2021-01-16            35140.6
# 320  2021-01-17            35341.4
# 321  2021-01-18            35620.2
#
# [322 rows x 2 columns]

# %%
fig3 = variable_visual.make_lineplot(data=df_json, x='Date', y='Total Deaths Mean', x_label='DATE', y_label='Total Deaths Mean', title='ANNEXED GROUP JSON LINE PLOT')

fig4 = variable_visual.make_barplot(data=df_json, x='Date', y='Total Deaths Mean', x_label='DATE', y_label='Total Deaths Mean', title='ANNEXED GROUP JSON BAR PLOT')
