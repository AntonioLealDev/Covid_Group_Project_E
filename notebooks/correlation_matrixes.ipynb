# %% [markdown]
# # EDA COVID PROJECT

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import import_ipynb
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
import second_cleaning_data as scd

# %% [markdown]
# ### Import modules

# %%
"""
Insert your file's path
"""

sys.path.append(os.path.dirname(os.path.dirname('C:\\Users\\usuario\\Desktop\\alumno_data_sciece\\data_science\\Trabajo_COVID_grupal\\notebooks\\correlation_matrixes')))

# %%
from src.utils import folders_tb as ft
from src.utils import mining_data_tb as mdt
from src.utils import visualization_tb as vt

# %% [markdown]
# ### Objetcs

# %%
variable_creator = ft.Folders()
variable_miner = mdt.Miner()
variable_visual = vt.Visualization()

# %% [markdown]
# ## Highest Correlation matrix (C)

# %%
# Matrix of every country correlation, where every variable have at least 0.9 correlation with another variable in the matrix

highest_poland_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_poland_masked_no_per, h=0.90)
highest_south_africa_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_south_africa_masked_no_per, h=0.90)
highest_indonesia_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_indonesia_masked_no_per, h=0.90)
highest_ukraine_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_ukraine_masked_no_per, h=0.90)
highest_spain_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_spain_masked_no_per , h=0.90)

# %%
# Visual representation of every matrix correlation

poland_matrix = variable_visual.correlation_matrix(matrix=highest_poland_correlation, title_1='POLAND CORRELATION')
south_africa_matrix = variable_visual.correlation_matrix(matrix=highest_south_africa_correlation, title_1='SOUTH AFRICA CORRELATION')
indonesia_matrix = variable_visual.correlation_matrix(matrix=highest_indonesia_correlation, title_1='INDONESIA CORRELATION')
ukraine_matrix = variable_visual.correlation_matrix(matrix=highest_ukraine_correlation, title_1='UKRAINE CORRELATION')
spain_matrix = variable_visual.correlation_matrix(matrix=highest_spain_correlation, title_1='SPAIN CORRELATION')

# %% [markdown]
# ## Top ten columns with the highest correlation (A)

# %%
# Matrix of every country top 10 correlation columns, where every variable in the matrix has at least one top 10 correlation with another variable in the amtrix.

top_10_highest_poland_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_poland_masked_no_per, h=0.88)
top_10_highest_south_africa_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_south_africa_masked_no_per, h=0.90)
top_10_highest_indonesia_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_indonesia_masked_no_per, h=0.54)
top_10_highest_ukraine_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_ukraine_masked_no_per, h=0.82)
top_10_highest_spain_correlation = variable_miner.highest_correlation_columns_per_country(dataset=scd.df_spain_masked_no_per , h=0.68)

# %%
# Visual representation of top 10 matrix correlation

poland_matrix = variable_visual.correlation_matrix(matrix=top_10_highest_poland_correlation, title_1='POLAND TOP 10 CORRELATION')
south_africa_matrix = variable_visual.correlation_matrix(matrix=top_10_highest_south_africa_correlation, title_1='SOUTH AFRICA TOP 10 CORRELATION')
indonesia_matrix = variable_visual.correlation_matrix(matrix=top_10_highest_indonesia_correlation, title_1='INDONESIA TOP 10 CORRELATION')
ukraine_matrix = variable_visual.correlation_matrix(matrix=top_10_highest_ukraine_correlation, title_1='UKRAINE TOP 10 CORRELATION')
spain_matrix = variable_visual.correlation_matrix(matrix=top_10_highest_spain_correlation, title_1='SPAIN TOP 10 CORRELATION')
